# %%
# !pip install kaggle

# %%
# import kaggle
# !kaggle datasets download -d ankitbansal06/retail-orders
# Out:
# HTTPSConnectionPool(host='www.kaggle.com', port=443): Max retries exceeded with url: /api/v1/datasets/metadata/ankitbansal06/retail-orders (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))

# %%
#extract zip file
import zipfile
zip_ref= zipfile.ZipFile('archive.zip')
zip_ref.extractall('orders.csv')
zip_ref.close()

# %%
# import pandas as pd
# df = pd.read_csv('orders.csv/orders.csv', na_values=['Not Available','unknown'])
df.head(20)

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
# rename column name and add under score

# df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent'],
#       dtype='object')

# %%
df.head()

# %%
# creating new columns 
# df['discount']= df['list_price']*df['discount_percent']*.01
df['sale_price'] = df['list_price']- df['discount']
df['profit'] = df['sale_price']- df['cost_price']
df

# %%
df.dtypes
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discount            float64
# sale_price          float64
# profit              float64
# dtype: object

# %%
import datetime as dt
df['order_date'] = pd.to_datetime(df['order_date'], format="%Y-%m-%d")
df.head()
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# sub_category                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# discount                   float64
# sale_price                 float64
# profit                     float64
# dtype: object

# %%
#dropping columns that are not needed


# if we add inplace=true, it will not return a new dataframe, it will modify the main dataframe
df.drop(columns=['list_price', 'discount_percent', 'cost_price'], inplace=True)

# %%
df
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
# the next step is to create a database and table in SQL, then we can insert this dataframe into the SQL table.
import pandas as pd
import sqlalchemy as sal
sql_engine= sal.create_engine('mssql:///orders.db')
conn= sql_engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 3
#       1 # the next step is to create a database and table in SQL, then we can insert this dataframe into the SQL table.
#       2 import pandas as pd
# ----> 3 import sqlalchemy as sal
#       4 sql_engine= sal.create_engine('mssql:///orders.db', echo=True)
#       5 conn= sql_engine.connect()
#
# ModuleNotFoundError: No module named 'sqlalchemy'
